# %%
import pandas as pd
import numpy as np

# %%
df_leads = pd.read_csv("../../data/leads_tests.csv")

# %%
df_company_global = df_leads[["Entreprise", "Contacté", "Notes", "website_url"]]

# %%
df_company_global
# Out:
#                         Entreprise Contacté  Notes  \
# 0                            iscod      Non    NaN
# 1              partners consulting      Non    NaN
# 2    armée de l'air et de l'espace      Non    NaN
# 3               galeries lafayette      Oui    NaN
# 4                 aureïs formation      Oui    NaN
# ..                             ...      ...    ...
# 469                fromageries bel      Non    NaN
# 470               frerejean freres      Non    NaN
# 471                 frans bonhomme      Non    NaN
# 472           france terre d'asile      Non    NaN
# 473                         élivie      Non    NaN
#
#                                            website_url
# 0                                https://www.iscod.fr/
# 1    https://www.partnersconsulting-of.com/page-de-...
# 2                      https://www.defense.gouv.fr/air
# 3                   https://www.galerieslafayette.com/
# 4                      https://www.aureisformation.fr/
# ...

# %%
df_company_global.loc[:, "activity_sector"] = np.nan

# %%
df_company_global
# Out:
#                         Entreprise Contacté  Notes  \
# 0                            iscod      Non    NaN
# 1              partners consulting      Non    NaN
# 2    armée de l'air et de l'espace      Non    NaN
# 3               galeries lafayette      Oui    NaN
# 4                 aureïs formation      Oui    NaN
# ..                             ...      ...    ...
# 469                fromageries bel      Non    NaN
# 470               frerejean freres      Non    NaN
# 471                 frans bonhomme      Non    NaN
# 472           france terre d'asile      Non    NaN
# 473                         élivie      Non    NaN
#
#                                            website_url  activity_sector
# 0                                https://www.iscod.fr/              NaN
# 1    https://www.partnersconsulting-of.com/page-de-...              NaN
# 2                      https://www.defense.gouv.fr/air              NaN
# ...

# %%
df_jobs = pd.read_csv("../../data/jobs_tests.csv", sep = ";", index_col = 0)

# %%
df_jobs.drop(columns = ["N.A."], inplace = True)

# %%
df_jobs
# Out:
#                                              job name  \
# 1                                Acheteur Travaux F/H
# 2                                 Acheteur Senior H/F
# 3                                 Acheteur public h/f
# 5                              Acheteur Transport F/H
# 9                    Acheteur Mode Femme Créateur H/F
# ..                                                ...
# 9   Gestionnaire administratif adidas (H/F/D) - 35...
# 10                                     OFFICE MANAGER
# 12     Office Manager Agence d'Architecture H/F Paris
# 13              Gestionnaire administratif polyvalent
# 14        Assistant de Direction / Office Manager H/F
#
#                                              company          location  \
# 1   FCAI (Fayat Construction Achats Investissements)  Roissy-en-France
# 2                          Groupe Chantelle Lingerie            Cachan
# 3                      Armée de l'Air et de l'Espace             Paris
# ...
