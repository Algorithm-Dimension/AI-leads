# %%
import pandas as pd

# %%
df_14 = pd.read_csv("data/leads_14_may.csv", sep=";")

# %%
df_5 = pd.read_csv("data/leads_tests_5_may_groq.csv", sep=";")

# %%
pd/concat()
# Out:
#                       Entreprise  source  \
# 0                         Safran  Indeed
# 1                Engie Solutions  Indeed
# 2                      Printemps  Indeed
# 3                     Swiss Life  Indeed
# 4                       Sogetrel  Indeed
# 5                          Sneci  Indeed
# 6                    Sncf Cadres  Indeed
# 7                   Paris Musées  Indeed
# 8                         Sferis  Indeed
# 9               Schindler France  Indeed
# 10                       Upercut  Indeed
# 11                  Saint Gobain  Indeed
# 12                Ville De Paris  Indeed
# 13            Sacatec Équipement  Indeed
# 14                          Ratp  Indeed
# 15                       Procemo  Indeed
# 16                   Alter Mundi  Indeed
# 17                   Mbda France  Indeed
# 18                        Amelia  Indeed
# 19                 Louis Vuitton  Indeed
# 20                  Logis Hotels  Indeed
# 21     La Chambre Aux Confitures  Indeed
# ...
